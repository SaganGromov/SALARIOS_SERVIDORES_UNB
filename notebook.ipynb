# %%
# Set display options to show the full output without truncation
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_colwidth', None)  # Show full column width
pd.set_option('display.expand_frame_repr', False)  # Prevent DataFrame from being split across lines

# %%
def format_brl(value: float) -> str:
    """
    Converts a float number into Brazilian Real (BRL) format.
    
    Args:
        value (float): The float number to be converted.
        
    Returns:
        str: The formatted string in BRL (e.g., 'R$ 14.547,45').
    """
    return f"R$ {value:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")

# %%
import pandas as pd
df = pd.read_csv('SALARIOS_SERVIDORES_UNB_AGOSTO.csv')
MAT = df[df['DEPARTAMENTO']=='DEPTO MATEMATICA'].copy()


def clean_currency(value):
    try:
        return float(value.replace('R$', '').replace('.', '').replace(',', '.').strip())
    except Exception as e:
        return 0
    
def limpar_rem(datafr):
    df = datafr
    df['REMUNERACAO BRUTA'] = df['REMUNERACAO BRUTA'].apply(clean_currency)
    df['REMUNERACAO LIQUIDA'] = df['REMUNERACAO LIQUIDA'].apply(clean_currency)
limpar_rem(MAT)
MAT.drop_duplicates(inplace=True)
# MAT_sorted = MAT.sort_values(by='REMUNERACAO BRUTA', ascending=False).reset_index(drop=True)
# MAT_sorted['Ranking'] = MAT_sorted['REMUNERACAO BRUTA'].rank(ascending=False, method='first').astype(int)
# ranking_list = list(MAT_sorted[['NOME', 'REMUNERACAO BRUTA', 'Ranking']].itertuples(index=False, name=None))
# for professor in ranking_list:
#     print("{lugar} lugar: {nome}, remuneração bruta de {rem}".format(nome = professor[0], lugar=professor[2], rem=professor[1]))
# Out:
# 1 lugar: NORAI ROMEU ROCCO, remuneração bruta de 29507.73
# 2 lugar: LILIANE DE ALMEIDA MAIA, remuneração bruta de 28886.66
# 3 lugar: MA TO FU, remuneração bruta de 27892.93
# 4 lugar: HEMAR TEIXEIRA GODINHO, remuneração bruta de 27550.22
# 5 lugar: PAVEL SHUMYATSKY, remuneração bruta de 26942.75
# 6 lugar: PAVEL ZALESSKI, remuneração bruta de 26821.26
# 7 lugar: ALEXEI KRASSILNIKOV, remuneração bruta de 26821.26
# 8 lugar: VICTOR PETROGRADSKIY, remuneração bruta de 26821.26
# 9 lugar: GIOVANY DE JESUS MALCHER FIGUEIREDO, remuneração bruta de 26527.1
# 10 lugar: CARLOS MABER CARRION RIVEROS, remuneração bruta de 26406.21
# 11 lugar: CARLOS ALBERTO PEREIRA DOS SANTOS, remuneração bruta de 26247.6
# 12 lugar: MARCELO FERNANDES FURTADO, remuneração bruta de 26247.6
# 13 lugar: ANGEL RODOLFO BAIGORRI, remuneração bruta de 25959.53
# 14 lugar: LUCIANA MARIA DIAS DE AVILA RODRIGUES, remuneração bruta de 25276.56
# 15 lugar: SHEILA CAMPOS CHAGAS, remuneração bruta de 24435.53
# 16 lugar: CATIA REGINA GONCALVES, remuneração bruta de 24371.85
# 17 lugar: WANG QIAOLING, remuneração bruta de 24213.25
